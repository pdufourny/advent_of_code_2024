# %%
with open("data1.txt") as f_in:
    corrupted_data= f_in.readlines()

# %%
print(len(corrupted_data))
# Out:
# 716

# %%
corrupted_data[0]
# Out:
# 'mul(363,974)\n'

# %%
corrupted_data[0].find("mul(",0)
# Out:
# 0

# %%
def get_mul_str(ligne,idx) -> (int,int,bool):
    pos = ligne.find("mul(",idx)
    if pos == -1:
        return 0,pos,False
    pos2 = ligne.find(")",pos+3)
    if pos2 == -1:
        return 0, pos2, False
    next_mul = ligne.find("mul(",pos +1)
    print(pos, pos2,next_mul)
    if next_mul < pos2 and next_mul != -1:
        return 0,next_mul,True    # cas ou un mul est inséré dans un mul
    the_mul = ligne[pos:pos2+1]
    print("A traiter : ",the_mul)
    # vérifier ici que les deux éléments sont bien 2 et que ce sont des nombres
    arguments = the_mul[4:-1].split(",")
    if len(arguments)!=2:
        return 0,pos2,True
    # ici, deux valeurs
    if not (arguments[0].isnumeric() and arguments[1].isnumeric()):
        print ("pas deux numeric")
        return 0,pos2,False
    else:
        print("==> OK")
        return int(arguments[0])*int(arguments[1]), pos2,True

# %%
get_mul_str(corrupted_data[0],0)
# Out:
# 0 11 -1
# A traiter :  mul(363,974)
# ==> OK
# (353562, 11, True)

# %%
sum_mul = 0

for ligne in corrupted_data:
    position = 0
    proceed = True
    while proceed :
        val,position,proceed = get_mul_str(ligne,position)
        sum_mul += val
        print(f"\t {val=}  {sum_mul= }")
    print("="*80)

print(sum_mul)
# Out:
# 0 11 -1
# A traiter :  mul(363,974)
# ==> OK
# 	 val=353562  sum_mul= 353562
# 	 val=0  sum_mul= 353562
# ================================================================================
# 0 11 -1
# A traiter :  mul(307,210)
# ==> OK
# 	 val=64470  sum_mul= 418032
# 	 val=0  sum_mul= 418032
# ================================================================================
# 0 11 -1
# A traiter :  mul(542,323)
# ==> OK
# 	 val=175066  sum_mul= 593098
# 	 val=0  sum_mul= 593098
# ================================================================================
# 0 11 -1
# A traiter :  mul(238,474)
# ==> OK
# 	 val=112812  sum_mul= 705910
# 	 val=0  sum_mul= 705910
# ================================================================================
# 0 11 -1
# A traiter :  mul(251,668)
# ==> OK
# 	 val=167668  sum_mul= 873578
# 	 val=0  sum_mul= 873578
# ================================================================================
# 0 11 -1
# A traiter :  mul(184,693)
# ==> OK
# 	 val=127512  sum_mul= 1001090
# 	 val=0  sum_mul= 1001090
# ================================================================================
# 0 10 -1
# A traiter :  mul(279,48)
# ==> OK
# 	 val=13392  sum_mul= 1014482
# 	 val=0  sum_mul= 1014482
# ================================================================================
# 0 10 -1
# A traiter :  mul(96,310)
# ==> OK
# 	 val=29760  sum_mul= 1044242
# 	 val=0  sum_mul= 1044242
# ================================================================================
# 0 11 -1
# A traiter :  mul(393,809)
# ==> OK
# 	 val=317937  sum_mul= 1362179
# 	 val=0  sum_mul= 1362179
# ================================================================================
# 0 10 -1
# A traiter :  mul(95,723)
# ==> OK
# 	 val=68685  sum_mul= 1430864
# 	 val=0  sum_mul= 1430864
# ================================================================================
# 0 9 -1
# A traiter :  mul(2,997)
# ==> OK
# 	 val=1994  sum_mul= 1432858
# 	 val=0  sum_mul= 1432858
# ================================================================================
# 0 11 -1
# A traiter :  mul(114,838)
# ==> OK
# 	 val=95532  sum_mul= 1528390
# 	 val=0  sum_mul= 1528390
# ================================================================================
# 0 11 -1
# A traiter :  mul(981,859)
# ==> OK
# 	 val=842679  sum_mul= 2371069
# 	 val=0  sum_mul= 2371069
# ================================================================================
# 0 11 -1
# A traiter :  mul(137,289)
# ==> OK
# 	 val=39593  sum_mul= 2410662
# 	 val=0  sum_mul= 2410662
# ================================================================================
# 0 11 -1
# A traiter :  mul(632,274)
# ==> OK
# 	 val=173168  sum_mul= 2583830
# 	 val=0  sum_mul= 2583830
# ================================================================================
# 0 11 -1
# A traiter :  mul(963,844)
# ==> OK
# 	 val=812772  sum_mul= 3396602
# 	 val=0  sum_mul= 3396602
# ================================================================================
# 0 11 -1
# A traiter :  mul(398,724)
# ==> OK
# 	 val=288152  sum_mul= 3684754
# 	 val=0  sum_mul= 3684754
# ================================================================================
# 0 10 -1
# A traiter :  mul(87,650)
# ==> OK
# 	 val=56550  sum_mul= 3741304
# 	 val=0  sum_mul= 3741304
# ================================================================================
# 0 11 -1
# A traiter :  mul(373,567)
# ==> OK
# 	 val=211491  sum_mul= 3952795
# 	 val=0  sum_mul= 3952795
# ================================================================================
# 0 11 -1
# A traiter :  mul(683,987)
# ==> OK
# 	 val=674121  sum_mul= 4626916
# 	 val=0  sum_mul= 4626916
# ================================================================================
# 0 11 -1
# A traiter :  mul(956,426)
# ==> OK
# 	 val=407256  sum_mul= 5034172
# 	 val=0  sum_mul= 5034172
# ================================================================================
# 0 10 -1
# A traiter :  mul(16,558)
# ==> OK
# 	 val=8928  sum_mul= 5043100
# 	 val=0  sum_mul= 5043100
# ================================================================================
# 0 11 -1
# A traiter :  mul(247,910)
# ==> OK
# 	 val=224770  sum_mul= 5267870
# 	 val=0  sum_mul= 5267870
# ================================================================================
# 0 10 -1
# A traiter :  mul(762,49)
# ==> OK
# 	 val=37338  sum_mul= 5305208
# 	 val=0  sum_mul= 5305208
# ================================================================================
# 0 11 -1
# A traiter :  mul(157,758)
# ==> OK
# 	 val=119006  sum_mul= 5424214
# 	 val=0  sum_mul= 5424214
# ================================================================================
# 0 11 -1
# A traiter :  mul(774,902)
# ==> OK
# 	 val=698148  sum_mul= 6122362
# 	 val=0  sum_mul= 6122362
# ================================================================================
# 0 11 -1
# A traiter :  mul(221,812)
# ==> OK
# 	 val=179452  sum_mul= 6301814
# 	 val=0  sum_mul= 6301814
# ================================================================================
# 0 11 -1
# A traiter :  mul(107,520)
# ==> OK
# 	 val=55640  sum_mul= 6357454
# 	 val=0  sum_mul= 6357454
# ================================================================================
# 0 11 -1
# A traiter :  mul(483,979)
# ==> OK
# 	 val=472857  sum_mul= 6830311
# 	 val=0  sum_mul= 6830311
# ================================================================================
# 0 11 -1
# A traiter :  mul(612,982)
# ==> OK
# 	 val=600984  sum_mul= 7431295
# 	 val=0  sum_mul= 7431295
# ================================================================================
# 0 11 -1
# A traiter :  mul(772,570)
# ==> OK
# 	 val=440040  sum_mul= 7871335
# 	 val=0  sum_mul= 7871335
# ================================================================================
# 0 11 -1
# A traiter :  mul(239,910)
# ==> OK
# 	 val=217490  sum_mul= 8088825
# 	 val=0  sum_mul= 8088825
# ================================================================================
# 0 9 -1
# A traiter :  mul(20,91)
# ==> OK
# 	 val=1820  sum_mul= 8090645
# 	 val=0  sum_mul= 8090645
# ================================================================================
# 0 10 -1
# A traiter :  mul(803,23)
# ==> OK
# 	 val=18469  sum_mul= 8109114
# 	 val=0  sum_mul= 8109114
# ================================================================================
# 0 11 -1
# A traiter :  mul(697,604)
# ==> OK
# 	 val=420988  sum_mul= 8530102
# 	 val=0  sum_mul= 8530102
# ================================================================================
# 0 10 -1
# A traiter :  mul(53,580)
# ==> OK
# 	 val=30740  sum_mul= 8560842
# 	 val=0  sum_mul= 8560842
# ================================================================================
# 0 10 -1
# A traiter :  mul(115,20)
# ==> OK
# 	 val=2300  sum_mul= 8563142
# 	 val=0  sum_mul= 8563142
# ================================================================================
# 0 11 -1
# A traiter :  mul(309,120)
# ==> OK
# 	 val=37080  sum_mul= 8600222
# 	 val=0  sum_mul= 8600222
# ================================================================================
# 0 11 -1
# A traiter :  mul(734,496)
# ==> OK
# 	 val=364064  sum_mul= 8964286
# 	 val=0  sum_mul= 8964286
# ================================================================================
# 0 11 -1
# A traiter :  mul(250,503)
# ==> OK
# 	 val=125750  sum_mul= 9090036
# 	 val=0  sum_mul= 9090036
# ================================================================================
# 0 11 -1
# A traiter :  mul(405,738)
# ==> OK
# 	 val=298890  sum_mul= 9388926
# 	 val=0  sum_mul= 9388926
# ================================================================================
# 0 10 -1
# A traiter :  mul(873,29)
# ==> OK
# 	 val=25317  sum_mul= 9414243
# 	 val=0  sum_mul= 9414243
# ================================================================================
# 0 11 -1
# A traiter :  mul(455,511)
# ==> OK
# 	 val=232505  sum_mul= 9646748
# 	 val=0  sum_mul= 9646748
# ================================================================================
# 0 11 -1
# A traiter :  mul(369,447)
# ==> OK
# 	 val=164943  sum_mul= 9811691
# 	 val=0  sum_mul= 9811691
# ================================================================================
# 0 11 -1
# A traiter :  mul(264,733)
# ==> OK
# 	 val=193512  sum_mul= 10005203
# 	 val=0  sum_mul= 10005203
# ================================================================================
# 0 11 -1
# A traiter :  mul(456,195)
# ==> OK
# 	 val=88920  sum_mul= 10094123
# 	 val=0  sum_mul= 10094123
# ================================================================================
# 0 11 -1
# A traiter :  mul(143,524)
# ==> OK
# 	 val=74932  sum_mul= 10169055
# 	 val=0  sum_mul= 10169055
# ================================================================================
# 0 11 -1
# A traiter :  mul(543,599)
# ==> OK
# 	 val=325257  sum_mul= 10494312
# 	 val=0  sum_mul= 10494312
# ================================================================================
# 0 11 -1
# A traiter :  mul(421,216)
# ==> OK
# 	 val=90936  sum_mul= 10585248
# 	 val=0  sum_mul= 10585248
# ================================================================================
# 0 11 -1
# A traiter :  mul(120,595)
# ==> OK
# 	 val=71400  sum_mul= 10656648
# 	 val=0  sum_mul= 10656648
# ================================================================================
# 0 11 -1
# A traiter :  mul(699,526)
# ==> OK
# 	 val=367674  sum_mul= 11024322
# 	 val=0  sum_mul= 11024322
# ================================================================================
# 0 10 -1
# A traiter :  mul(545,69)
# ==> OK
# 	 val=37605  sum_mul= 11061927
# 	 val=0  sum_mul= 11061927
# ================================================================================
# 0 11 -1
# A traiter :  mul(360,401)
# ==> OK
# 	 val=144360  sum_mul= 11206287
# 	 val=0  sum_mul= 11206287
# ================================================================================
# 0 10 -1
# A traiter :  mul(877,27)
# ==> OK
# 	 val=23679  sum_mul= 11229966
# 	 val=0  sum_mul= 11229966
# ================================================================================
# 0 11 -1
# A traiter :  mul(788,890)
# ==> OK
# 	 val=701320  sum_mul= 11931286
# 	 val=0  sum_mul= 11931286
# ================================================================================
# 0 11 -1
# A traiter :  mul(354,988)
# ==> OK
# 	 val=349752  sum_mul= 12281038
# 	 val=0  sum_mul= 12281038
# ================================================================================
# 0 11 -1
# A traiter :  mul(817,116)
# ==> OK
# 	 val=94772  sum_mul= 12375810
# 	 val=0  sum_mul= 12375810
# ================================================================================
# 0 11 -1
# A traiter :  mul(935,628)
# ==> OK
# 	 val=587180  sum_mul= 12962990
# 	 val=0  sum_mul= 12962990
# ================================================================================
# 0 11 -1
# A traiter :  mul(391,670)
# ==> OK
# 	 val=261970  sum_mul= 13224960
# 	 val=0  sum_mul= 13224960
# ================================================================================
# 0 11 -1
# A traiter :  mul(797,795)
# ==> OK
# 	 val=633615  sum_mul= 13858575
# 	 val=0  sum_mul= 13858575
# ================================================================================
# 0 11 -1
# A traiter :  mul(729,920)
# ==> OK
# 	 val=670680  sum_mul= 14529255
# 	 val=0  sum_mul= 14529255
# ================================================================================
# 0 11 -1
# A traiter :  mul(640,560)
# ==> OK
# 	 val=358400  sum_mul= 14887655
# 	 val=0  sum_mul= 14887655
# ================================================================================
# 0 11 -1
# A traiter :  mul(680,451)
# ==> OK
# 	 val=306680  sum_mul= 15194335
# 	 val=0  sum_mul= 15194335
# ================================================================================
# 0 11 -1
# A traiter :  mul(479,397)
# ==> OK
# 	 val=190163  sum_mul= 15384498
# 	 val=0  sum_mul= 15384498
# ================================================================================
# 0 11 -1
# A traiter :  mul(575,201)
# ==> OK
# 	 val=115575  sum_mul= 15500073
# 	 val=0  sum_mul= 15500073
# ================================================================================
# 0 11 -1
# A traiter :  mul(209,486)
# ==> OK
# 	 val=101574  sum_mul= 15601647
# 	 val=0  sum_mul= 15601647
# ================================================================================
# 0 11 -1
# A traiter :  mul(628,607)
# ==> OK
# 	 val=381196  sum_mul= 15982843
# 	 val=0  sum_mul= 15982843
# ================================================================================
# 0 11 -1
# A traiter :  mul(956,696)
# ==> OK
# 	 val=665376  sum_mul= 16648219
# 	 val=0  sum_mul= 16648219
# ================================================================================
# 0 11 -1
# A traiter :  mul(337,228)
# ==> OK
# 	 val=76836  sum_mul= 16725055
# 	 val=0  sum_mul= 16725055
# ================================================================================
# 0 9 -1
# A traiter :  mul(7,646)
# ==> OK
# 	 val=4522  sum_mul= 16729577
# 	 val=0  sum_mul= 16729577
# ================================================================================
# 0 10 -1
# A traiter :  mul(933,32)
# ==> OK
# 	 val=29856  sum_mul= 16759433
# 	 val=0  sum_mul= 16759433
# ================================================================================
# 0 11 -1
# A traiter :  mul(751,249)
# ==> OK
# 	 val=186999  sum_mul= 16946432
# 	 val=0  sum_mul= 16946432
# ================================================================================
# 0 11 -1
# A traiter :  mul(774,589)
# ==> OK
# 	 val=455886  sum_mul= 17402318
# 	 val=0  sum_mul= 17402318
# ================================================================================
# 0 11 -1
# A traiter :  mul(901,340)
# ==> OK
# 	 val=306340  sum_mul= 17708658
# 	 val=0  sum_mul= 17708658
# ================================================================================
# 0 11 -1
# A traiter :  mul(135,980)
# ==> OK
# 	 val=132300  sum_mul= 17840958
# 	 val=0  sum_mul= 17840958
# ================================================================================
# 0 10 -1
# A traiter :  mul(60,218)
# ==> OK
# 	 val=13080  sum_mul= 17854038
# 	 val=0  sum_mul= 17854038
# ================================================================================
# 0 11 -1
# A traiter :  mul(338,605)
# ==> OK
# 	 val=204490  sum_mul= 18058528
# 	 val=0  sum_mul= 18058528
# ================================================================================
# 0 11 -1
# A traiter :  mul(843,237)
# ==> OK
# 	 val=199791  sum_mul= 18258319
# 	 val=0  sum_mul= 18258319
# ================================================================================
# 0 11 -1
# A traiter :  mul(851,111)
# ==> OK
# 	 val=94461  sum_mul= 18352780
# 	 val=0  sum_mul= 18352780
# ================================================================================
# 0 9 -1
# A traiter :  mul(97,70)
# ==> OK
# 	 val=6790  sum_mul= 18359570
# 	 val=0  sum_mul= 18359570
# ================================================================================
# 0 11 -1
# A traiter :  mul(993,750)
# ==> OK
# 	 val=744750  sum_mul= 19104320
# 	 val=0  sum_mul= 19104320
# ================================================================================
# 0 11 -1
# A traiter :  mul(449,205)
# ==> OK
# 	 val=92045  sum_mul= 19196365
# 	 val=0  sum_mul= 19196365
# ================================================================================
# 0 11 -1
# A traiter :  mul(394,163)
# ==> OK
# 	 val=64222  sum_mul= 19260587
# 	 val=0  sum_mul= 19260587
# ================================================================================
# 0 9 -1
# A traiter :  mul(48,70)
# ==> OK
# 	 val=3360  sum_mul= 19263947
# 	 val=0  sum_mul= 19263947
# ================================================================================
# 0 10 -1
# A traiter :  mul(89,545)
# ==> OK
# 	 val=48505  sum_mul= 19312452
# 	 val=0  sum_mul= 19312452
# ================================================================================
# 0 11 -1
# A traiter :  mul(283,275)
# ==> OK
# 	 val=77825  sum_mul= 19390277
# 	 val=0  sum_mul= 19390277
# ================================================================================
# 0 11 -1
# A traiter :  mul(749,362)
# ==> OK
# 	 val=271138  sum_mul= 19661415
# 	 val=0  sum_mul= 19661415
# ================================================================================
# 0 11 -1
# A traiter :  mul(410,531)
# ==> OK
# 	 val=217710  sum_mul= 19879125
# 	 val=0  sum_mul= 19879125
# ================================================================================
# 0 11 -1
# A traiter :  mul(230,723)
# ==> OK
# 	 val=166290  sum_mul= 20045415
# 	 val=0  sum_mul= 20045415
# ================================================================================
# 0 11 -1
# A traiter :  mul(740,611)
# ==> OK
# 	 val=452140  sum_mul= 20497555
# 	 val=0  sum_mul= 20497555
# ================================================================================
# 0 11 -1
# A traiter :  mul(740,976)
# ==> OK
# 	 val=722240  sum_mul= 21219795
# 	 val=0  sum_mul= 21219795
# ================================================================================
# 0 10 -1
# A traiter :  mul(632,54)
# ==> OK
# 	 val=34128  sum_mul= 21253923
# 	 val=0  sum_mul= 21253923
# ================================================================================
# 0 11 -1
# A traiter :  mul(227,473)
# ==> OK
# 	 val=107371  sum_mul= 21361294
# 	 val=0  sum_mul= 21361294
# ================================================================================
# 0 10 -1
# A traiter :  mul(42,366)
# ==> OK
# 	 val=15372  sum_mul= 21376666
# 	 val=0  sum_mul= 21376666
# ================================================================================
# 0 11 -1
# A traiter :  mul(858,853)
# ==> OK
# 	 val=731874  sum_mul= 22108540
# 	 val=0  sum_mul= 22108540
# ================================================================================
# 0 11 -1
# A traiter :  mul(120,626)
# ==> OK
# 	 val=75120  sum_mul= 22183660
# 	 val=0  sum_mul= 22183660
# ================================================================================
# 0 11 -1
# A traiter :  mul(764,724)
# ==> OK
# 	 val=553136  sum_mul= 22736796
# 	 val=0  sum_mul= 22736796
# ================================================================================
# 0 10 -1
# A traiter :  mul(786,24)
# ==> OK
# 	 val=18864  sum_mul= 22755660
# 	 val=0  sum_mul= 22755660
# ================================================================================
# 0 11 -1
# A traiter :  mul(217,355)
# ==> OK
# 	 val=77035  sum_mul= 22832695
# 	 val=0  sum_mul= 22832695
# ================================================================================
# 0 11 -1
# A traiter :  mul(836,446)
# ==> OK
# 	 val=372856  sum_mul= 23205551
# 	 val=0  sum_mul= 23205551
# ================================================================================
# 0 11 -1
# A traiter :  mul(286,660)
# ==> OK
# 	 val=188760  sum_mul= 23394311
# 	 val=0  sum_mul= 23394311
# ================================================================================
# 0 10 -1
# A traiter :  mul(52,893)
# ==> OK
# 	 val=46436  sum_mul= 23440747
# 	 val=0  sum_mul= 23440747
# ================================================================================
# 0 10 -1
# A traiter :  mul(786,11)
# ==> OK
# 	 val=8646  sum_mul= 23449393
# 	 val=0  sum_mul= 23449393
# ================================================================================
# 0 11 -1
# A traiter :  mul(592,549)
# ==> OK
# 	 val=325008  sum_mul= 23774401
# 	 val=0  sum_mul= 23774401
# ================================================================================
# 0 11 -1
# A traiter :  mul(144,388)
# ==> OK
# 	 val=55872  sum_mul= 23830273
# 	 val=0  sum_mul= 23830273
# ================================================================================
# 0 10 -1
# A traiter :  mul(354,60)
# ==> OK
# 	 val=21240  sum_mul= 23851513
# 	 val=0  sum_mul= 23851513
# ================================================================================
# 0 11 -1
# A traiter :  mul(836,693)
# ==> OK
# 	 val=579348  sum_mul= 24430861
# 	 val=0  sum_mul= 24430861
# ================================================================================
# 0 10 -1
# A traiter :  mul(589,16)
# ==> OK
# 	 val=9424  sum_mul= 24440285
# 	 val=0  sum_mul= 24440285
# ================================================================================
# 0 11 -1
# A traiter :  mul(693,551)
# ==> OK
# 	 val=381843  sum_mul= 24822128
# 	 val=0  sum_mul= 24822128
# ================================================================================
# 0 11 -1
# A traiter :  mul(332,717)
# ==> OK
# 	 val=238044  sum_mul= 25060172
# 	 val=0  sum_mul= 25060172
# ================================================================================
# 0 11 -1
# A traiter :  mul(928,751)
# ==> OK
# 	 val=696928  sum_mul= 25757100
# 	 val=0  sum_mul= 25757100
# ================================================================================
# 0 11 -1
# A traiter :  mul(712,589)
# ==> OK
# 	 val=419368  sum_mul= 26176468
# 	 val=0  sum_mul= 26176468
# ================================================================================
# 0 11 -1
# A traiter :  mul(247,213)
# ==> OK
# 	 val=52611  sum_mul= 26229079
# 	 val=0  sum_mul= 26229079
# ================================================================================
# 0 9 -1
# A traiter :  mul(8,280)
# ==> OK
# 	 val=2240  sum_mul= 26231319
# 	 val=0  sum_mul= 26231319
# ================================================================================
# 0 11 -1
# A traiter :  mul(152,494)
# ==> OK
# 	 val=75088  sum_mul= 26306407
# 	 val=0  sum_mul= 26306407
# ================================================================================
# 0 11 -1
# A traiter :  mul(405,165)
# ==> OK
# 	 val=66825  sum_mul= 26373232
# 	 val=0  sum_mul= 26373232
# ================================================================================
# 0 9 -1
# A traiter :  mul(459,2)
# ==> OK
# 	 val=918  sum_mul= 26374150
# 	 val=0  sum_mul= 26374150
# ================================================================================
# 0 11 -1
# A traiter :  mul(163,810)
# ==> OK
# 	 val=132030  sum_mul= 26506180
# 	 val=0  sum_mul= 26506180
# ================================================================================
# 0 11 -1
# A traiter :  mul(526,640)
# ==> OK
# 	 val=336640  sum_mul= 26842820
# 	 val=0  sum_mul= 26842820
# ================================================================================
# 0 11 -1
# A traiter :  mul(683,368)
# ==> OK
# 	 val=251344  sum_mul= 27094164
# 	 val=0  sum_mul= 27094164
# ================================================================================
# 0 11 -1
# A traiter :  mul(870,144)
# ==> OK
# 	 val=125280  sum_mul= 27219444
# 	 val=0  sum_mul= 27219444
# ================================================================================
# 0 11 -1
# A traiter :  mul(546,403)
# ==> OK
# 	 val=220038  sum_mul= 27439482
# 	 val=0  sum_mul= 27439482
# ================================================================================
# 0 11 -1
# A traiter :  mul(978,991)
# ==> OK
# 	 val=969198  sum_mul= 28408680
# 	 val=0  sum_mul= 28408680
# ================================================================================
# 0 11 -1
# A traiter :  mul(198,908)
# ==> OK
# 	 val=179784  sum_mul= 28588464
# 	 val=0  sum_mul= 28588464
# ================================================================================
# 0 10 -1
# A traiter :  mul(367,32)
# ==> OK
# 	 val=11744  sum_mul= 28600208
# 	 val=0  sum_mul= 28600208
# ================================================================================
# 0 10 -1
# A traiter :  mul(999,50)
# ==> OK
# 	 val=49950  sum_mul= 28650158
# 	 val=0  sum_mul= 28650158
# ================================================================================
# 0 11 -1
# A traiter :  mul(440,800)
# ==> OK
# 	 val=352000  sum_mul= 29002158
# 	 val=0  sum_mul= 29002158
# ================================================================================
# 0 11 -1
# A traiter :  mul(831,741)
# ==> OK
# 	 val=615771  sum_mul= 29617929
# 	 val=0  sum_mul= 29617929
# ================================================================================
# 0 11 -1
# A traiter :  mul(388,682)
# ==> OK
# 	 val=264616  sum_mul= 29882545
# 	 val=0  sum_mul= 29882545
# ================================================================================
# 0 11 -1
# A traiter :  mul(891,251)
# ==> OK
# 	 val=223641  sum_mul= 30106186
# 	 val=0  sum_mul= 30106186
# ================================================================================
# 0 11 -1
# A traiter :  mul(280,330)
# ==> OK
# 	 val=92400  sum_mul= 30198586
# 	 val=0  sum_mul= 30198586
# ================================================================================
# 0 11 -1
# A traiter :  mul(488,154)
# ==> OK
# 	 val=75152  sum_mul= 30273738
# 	 val=0  sum_mul= 30273738
# ================================================================================
# 0 11 -1
# A traiter :  mul(195,270)
# ==> OK
# 	 val=52650  sum_mul= 30326388
# 	 val=0  sum_mul= 30326388
# ================================================================================
# 0 11 -1
# A traiter :  mul(712,540)
# ==> OK
# 	 val=384480  sum_mul= 30710868
# 	 val=0  sum_mul= 30710868
# ================================================================================
# 0 11 -1
# A traiter :  mul(598,606)
# ==> OK
# 	 val=362388  sum_mul= 31073256
# 	 val=0  sum_mul= 31073256
# ================================================================================
# 0 11 -1
# A traiter :  mul(671,368)
# ==> OK
# 	 val=246928  sum_mul= 31320184
# 	 val=0  sum_mul= 31320184
# ================================================================================
# 0 11 -1
# A traiter :  mul(988,923)
# ==> OK
# 	 val=911924  sum_mul= 32232108
# 	 val=0  sum_mul= 32232108
# ================================================================================
# 0 11 -1
# A traiter :  mul(922,941)
# ==> OK
# 	 val=867602  sum_mul= 33099710
# 	 val=0  sum_mul= 33099710
# ================================================================================
# 0 11 -1
# A traiter :  mul(478,403)
# ==> OK
# 	 val=192634  sum_mul= 33292344
# 	 val=0  sum_mul= 33292344
# ================================================================================
# 0 11 -1
# A traiter :  mul(879,749)
# ==> OK
# 	 val=658371  sum_mul= 33950715
# 	 val=0  sum_mul= 33950715
# ================================================================================
# 0 11 -1
# A traiter :  mul(496,153)
# ==> OK
# 	 val=75888  sum_mul= 34026603
# 	 val=0  sum_mul= 34026603
# ================================================================================
# 0 11 -1
# A traiter :  mul(744,112)
# ==> OK
# 	 val=83328  sum_mul= 34109931
# 	 val=0  sum_mul= 34109931
# ================================================================================
# 0 10 -1
# A traiter :  mul(38,905)
# ==> OK
# 	 val=34390  sum_mul= 34144321
# 	 val=0  sum_mul= 34144321
# ================================================================================
# 0 11 -1
# A traiter :  mul(471,368)
# ==> OK
# 	 val=173328  sum_mul= 34317649
# 	 val=0  sum_mul= 34317649
# ================================================================================
# 0 10 -1
# A traiter :  mul(74,524)
# ==> OK
# 	 val=38776  sum_mul= 34356425
# 	 val=0  sum_mul= 34356425
# ================================================================================
# 0 11 -1
# A traiter :  mul(630,441)
# ==> OK
# 	 val=277830  sum_mul= 34634255
# 	 val=0  sum_mul= 34634255
# ================================================================================
# 0 10 -1
# A traiter :  mul(305,93)
# ==> OK
# 	 val=28365  sum_mul= 34662620
# 	 val=0  sum_mul= 34662620
# ================================================================================
# 0 11 -1
# A traiter :  mul(302,894)
# ==> OK
# 	 val=269988  sum_mul= 34932608
# 	 val=0  sum_mul= 34932608
# ================================================================================
# 0 11 -1
# A traiter :  mul(399,943)
# ==> OK
# 	 val=376257  sum_mul= 35308865
# 	 val=0  sum_mul= 35308865
# ================================================================================
# 0 11 -1
# A traiter :  mul(692,228)
# ==> OK
# 	 val=157776  sum_mul= 35466641
# 	 val=0  sum_mul= 35466641
# ================================================================================
# 0 10 -1
# A traiter :  mul(48,961)
# ==> OK
# 	 val=46128  sum_mul= 35512769
# 	 val=0  sum_mul= 35512769
# ================================================================================
# 0 11 -1
# A traiter :  mul(689,961)
# ==> OK
# 	 val=662129  sum_mul= 36174898
# 	 val=0  sum_mul= 36174898
# ================================================================================
# 0 10 -1
# A traiter :  mul(62,444)
# ==> OK
# 	 val=27528  sum_mul= 36202426
# 	 val=0  sum_mul= 36202426
# ================================================================================
# 0 11 -1
# A traiter :  mul(796,544)
# ==> OK
# 	 val=433024  sum_mul= 36635450
# 	 val=0  sum_mul= 36635450
# ================================================================================
# 0 11 -1
# A traiter :  mul(189,990)
# ==> OK
# 	 val=187110  sum_mul= 36822560
# 	 val=0  sum_mul= 36822560
# ================================================================================
# 0 11 -1
# A traiter :  mul(771,579)
# ==> OK
# 	 val=446409  sum_mul= 37268969
# 	 val=0  sum_mul= 37268969
# ================================================================================
# 0 11 -1
# A traiter :  mul(639,704)
# ==> OK
# 	 val=449856  sum_mul= 37718825
# 	 val=0  sum_mul= 37718825
# ================================================================================
# 0 11 -1
# A traiter :  mul(184,932)
# ==> OK
# 	 val=171488  sum_mul= 37890313
# 	 val=0  sum_mul= 37890313
# ================================================================================
# 0 11 -1
# A traiter :  mul(266,362)
# ==> OK
# 	 val=96292  sum_mul= 37986605
# 	 val=0  sum_mul= 37986605
# ================================================================================
# 0 11 -1
# A traiter :  mul(982,606)
# ==> OK
# 	 val=595092  sum_mul= 38581697
# 	 val=0  sum_mul= 38581697
# ================================================================================
# 0 11 -1
# A traiter :  mul(271,864)
# ==> OK
# 	 val=234144  sum_mul= 38815841
# 	 val=0  sum_mul= 38815841
# ================================================================================
# 0 11 -1
# A traiter :  mul(344,567)
# ==> OK
# 	 val=195048  sum_mul= 39010889
# 	 val=0  sum_mul= 39010889
# ================================================================================
# 0 11 -1
# A traiter :  mul(634,681)
# ==> OK
# 	 val=431754  sum_mul= 39442643
# 	 val=0  sum_mul= 39442643
# ================================================================================
# 	 val=0  sum_mul= 39442643
# ================================================================================
# 0 11 -1
# A traiter :  mul(687,593)
# ==> OK
# 	 val=407391  sum_mul= 39850034
# 	 val=0  sum_mul= 39850034
# ================================================================================
# 0 11 -1
# A traiter :  mul(649,253)
# ==> OK
# 	 val=164197  sum_mul= 40014231
# 	 val=0  sum_mul= 40014231
# ================================================================================
# 0 11 -1
# A traiter :  mul(601,326)
# ==> OK
# 	 val=195926  sum_mul= 40210157
# 	 val=0  sum_mul= 40210157
# ================================================================================
# 0 10 -1
# A traiter :  mul(50,494)
# ==> OK
# 	 val=24700  sum_mul= 40234857
# 	 val=0  sum_mul= 40234857
# ================================================================================
# 0 11 -1
# A traiter :  mul(973,228)
# ==> OK
# 	 val=221844  sum_mul= 40456701
# 	 val=0  sum_mul= 40456701
# ================================================================================
# 0 11 -1
# A traiter :  mul(824,775)
# ==> OK
# 	 val=638600  sum_mul= 41095301
# 	 val=0  sum_mul= 41095301
# ================================================================================
# 0 11 -1
# A traiter :  mul(733,837)
# ==> OK
# 	 val=613521  sum_mul= 41708822
# 	 val=0  sum_mul= 41708822
# ================================================================================
# 0 10 -1
# A traiter :  mul(37,354)
# ==> OK
# 	 val=13098  sum_mul= 41721920
# 	 val=0  sum_mul= 41721920
# ================================================================================
# 0 11 -1
# A traiter :  mul(531,743)
# ==> OK
# 	 val=394533  sum_mul= 42116453
# 	 val=0  sum_mul= 42116453
# ================================================================================
# 0 11 -1
# A traiter :  mul(717,933)
# ==> OK
# 	 val=668961  sum_mul= 42785414
# 	 val=0  sum_mul= 42785414
# ================================================================================
# 0 11 -1
# A traiter :  mul(152,466)
# ==> OK
# 	 val=70832  sum_mul= 42856246
# 	 val=0  sum_mul= 42856246
# ================================================================================
# 0 11 -1
# A traiter :  mul(989,170)
# ==> OK
# 	 val=168130  sum_mul= 43024376
# 	 val=0  sum_mul= 43024376
# ================================================================================
# 0 11 -1
# A traiter :  mul(428,952)
# ==> OK
# 	 val=407456  sum_mul= 43431832
# 	 val=0  sum_mul= 43431832
# ================================================================================
# 0 11 -1
# A traiter :  mul(631,936)
# ==> OK
# 	 val=590616  sum_mul= 44022448
# 	 val=0  sum_mul= 44022448
# ================================================================================
# 0 11 -1
# A traiter :  mul(324,717)
# ==> OK
# 	 val=232308  sum_mul= 44254756
# 	 val=0  sum_mul= 44254756
# ================================================================================
# 0 11 -1
# A traiter :  mul(798,983)
# ==> OK
# 	 val=784434  sum_mul= 45039190
# 	 val=0  sum_mul= 45039190
# ================================================================================
# 0 11 -1
# A traiter :  mul(634,416)
# ==> OK
# 	 val=263744  sum_mul= 45302934
# 	 val=0  sum_mul= 45302934
# ================================================================================
# 0 10 -1
# A traiter :  mul(502,68)
# ==> OK
# 	 val=34136  sum_mul= 45337070
# 	 val=0  sum_mul= 45337070
# ================================================================================
# 0 11 -1
# A traiter :  mul(139,235)
# ==> OK
# 	 val=32665  sum_mul= 45369735
# 	 val=0  sum_mul= 45369735
# ================================================================================
# 0 10 -1
# A traiter :  mul(46,583)
# ==> OK
# 	 val=26818  sum_mul= 45396553
# 	 val=0  sum_mul= 45396553
# ================================================================================
# 0 10 -1
# A traiter :  mul(63,521)
# ==> OK
# 	 val=32823  sum_mul= 45429376
# 	 val=0  sum_mul= 45429376
# ================================================================================
# 0 11 -1
# A traiter :  mul(936,920)
# ==> OK
# 	 val=861120  sum_mul= 46290496
# 	 val=0  sum_mul= 46290496
# ================================================================================
# 0 11 -1
# A traiter :  mul(575,226)
# ==> OK
# 	 val=129950  sum_mul= 46420446
# 	 val=0  sum_mul= 46420446
# ================================================================================
# 0 11 -1
# A traiter :  mul(973,174)
# ==> OK
# 	 val=169302  sum_mul= 46589748
# 	 val=0  sum_mul= 46589748
# ================================================================================
# 0 10 -1
# A traiter :  mul(38,795)
# ==> OK
# 	 val=30210  sum_mul= 46619958
# 	 val=0  sum_mul= 46619958
# ================================================================================
# 0 11 -1
# A traiter :  mul(831,459)
# ==> OK
# 	 val=381429  sum_mul= 47001387
# 	 val=0  sum_mul= 47001387
# ================================================================================
# 0 11 -1
# A traiter :  mul(824,693)
# ==> OK
# 	 val=571032  sum_mul= 47572419
# 	 val=0  sum_mul= 47572419
# ================================================================================
# 0 10 -1
# A traiter :  mul(88,768)
# ==> OK
# 	 val=67584  sum_mul= 47640003
# 	 val=0  sum_mul= 47640003
# ================================================================================
# 0 11 -1
# A traiter :  mul(300,552)
# ==> OK
# 	 val=165600  sum_mul= 47805603
# 	 val=0  sum_mul= 47805603
# ================================================================================
# 0 11 -1
# A traiter :  mul(237,143)
# ==> OK
# 	 val=33891  sum_mul= 47839494
# 	 val=0  sum_mul= 47839494
# ================================================================================
# 0 11 -1
# A traiter :  mul(189,113)
# ==> OK
# 	 val=21357  sum_mul= 47860851
# 	 val=0  sum_mul= 47860851
# ================================================================================
# 0 11 -1
# A traiter :  mul(100,932)
# ==> OK
# 	 val=93200  sum_mul= 47954051
# 	 val=0  sum_mul= 47954051
# ================================================================================
# 0 11 -1
# A traiter :  mul(868,798)
# ==> OK
# 	 val=692664  sum_mul= 48646715
# 	 val=0  sum_mul= 48646715
# ================================================================================
# 0 11 -1
# A traiter :  mul(321,726)
# ==> OK
# 	 val=233046  sum_mul= 48879761
# 	 val=0  sum_mul= 48879761
# ================================================================================
# 0 11 -1
# A traiter :  mul(495,108)
# ==> OK
# 	 val=53460  sum_mul= 48933221
# 	 val=0  sum_mul= 48933221
# ================================================================================
# 0 11 -1
# A traiter :  mul(623,365)
# ==> OK
# 	 val=227395  sum_mul= 49160616
# 	 val=0  sum_mul= 49160616
# ================================================================================
# 0 11 -1
# A traiter :  mul(227,970)
# ==> OK
# 	 val=220190  sum_mul= 49380806
# 	 val=0  sum_mul= 49380806
# ================================================================================
# 0 11 -1
# A traiter :  mul(341,808)
# ==> OK
# 	 val=275528  sum_mul= 49656334
# 	 val=0  sum_mul= 49656334
# ================================================================================
# 0 10 -1
# A traiter :  mul(978,75)
# ==> OK
# 	 val=73350  sum_mul= 49729684
# 	 val=0  sum_mul= 49729684
# ================================================================================
# 0 11 -1
# A traiter :  mul(913,501)
# ==> OK
# 	 val=457413  sum_mul= 50187097
# 	 val=0  sum_mul= 50187097
# ================================================================================
# 0 11 -1
# A traiter :  mul(474,616)
# ==> OK
# 	 val=291984  sum_mul= 50479081
# 	 val=0  sum_mul= 50479081
# ================================================================================
# 0 10 -1
# A traiter :  mul(22,758)
# ==> OK
# 	 val=16676  sum_mul= 50495757
# 	 val=0  sum_mul= 50495757
# ================================================================================
# 0 11 -1
# A traiter :  mul(572,786)
# ==> OK
# 	 val=449592  sum_mul= 50945349
# 	 val=0  sum_mul= 50945349
# ================================================================================
# 0 11 -1
# A traiter :  mul(853,705)
# ==> OK
# 	 val=601365  sum_mul= 51546714
# 	 val=0  sum_mul= 51546714
# ================================================================================
# 0 11 -1
# A traiter :  mul(635,594)
# ==> OK
# 	 val=377190  sum_mul= 51923904
# 	 val=0  sum_mul= 51923904
# ================================================================================
# 0 11 -1
# A traiter :  mul(650,664)
# ==> OK
# 	 val=431600  sum_mul= 52355504
# 	 val=0  sum_mul= 52355504
# ================================================================================
# 0 11 -1
# A traiter :  mul(214,598)
# ==> OK
# 	 val=127972  sum_mul= 52483476
# 	 val=0  sum_mul= 52483476
# ================================================================================
# 0 11 -1
# A traiter :  mul(863,622)
# ==> OK
# 	 val=536786  sum_mul= 53020262
# 	 val=0  sum_mul= 53020262
# ================================================================================
# 0 11 -1
# A traiter :  mul(418,861)
# ==> OK
# 	 val=359898  sum_mul= 53380160
# 	 val=0  sum_mul= 53380160
# ================================================================================
# 0 10 -1
# A traiter :  mul(52,353)
# ==> OK
# 	 val=18356  sum_mul= 53398516
# 	 val=0  sum_mul= 53398516
# ================================================================================
# 0 11 -1
# A traiter :  mul(879,737)
# ==> OK
# 	 val=647823  sum_mul= 54046339
# 	 val=0  sum_mul= 54046339
# ================================================================================
# 0 11 -1
# A traiter :  mul(652,883)
# ==> OK
# 	 val=575716  sum_mul= 54622055
# 	 val=0  sum_mul= 54622055
# ================================================================================
# 0 11 -1
# A traiter :  mul(965,310)
# ==> OK
# 	 val=299150  sum_mul= 54921205
# 	 val=0  sum_mul= 54921205
# ================================================================================
# 0 11 -1
# A traiter :  mul(309,214)
# ==> OK
# 	 val=66126  sum_mul= 54987331
# 	 val=0  sum_mul= 54987331
# ================================================================================
# 0 11 -1
# A traiter :  mul(223,518)
# ==> OK
# 	 val=115514  sum_mul= 55102845
# 	 val=0  sum_mul= 55102845
# ================================================================================
# 0 11 -1
# A traiter :  mul(784,871)
# ==> OK
# 	 val=682864  sum_mul= 55785709
# 	 val=0  sum_mul= 55785709
# ================================================================================
# 0 11 -1
# A traiter :  mul(417,412)
# ==> OK
# 	 val=171804  sum_mul= 55957513
# 	 val=0  sum_mul= 55957513
# ================================================================================
# 0 11 -1
# A traiter :  mul(589,146)
# ==> OK
# 	 val=85994  sum_mul= 56043507
# 	 val=0  sum_mul= 56043507
# ================================================================================
# 0 11 -1
# A traiter :  mul(723,893)
# ==> OK
# 	 val=645639  sum_mul= 56689146
# 	 val=0  sum_mul= 56689146
# ================================================================================
# 0 10 -1
# A traiter :  mul(701,35)
# ==> OK
# 	 val=24535  sum_mul= 56713681
# 	 val=0  sum_mul= 56713681
# ================================================================================
# 0 11 -1
# A traiter :  mul(844,568)
# ==> OK
# 	 val=479392  sum_mul= 57193073
# 	 val=0  sum_mul= 57193073
# ================================================================================
# 0 11 -1
# A traiter :  mul(223,160)
# ==> OK
# 	 val=35680  sum_mul= 57228753
# 	 val=0  sum_mul= 57228753
# ================================================================================
# 0 10 -1
# A traiter :  mul(775,44)
# ==> OK
# 	 val=34100  sum_mul= 57262853
# 	 val=0  sum_mul= 57262853
# ================================================================================
# 0 11 -1
# A traiter :  mul(101,358)
# ==> OK
# 	 val=36158  sum_mul= 57299011
# 	 val=0  sum_mul= 57299011
# ================================================================================
# 0 11 -1
# A traiter :  mul(160,603)
# ==> OK
# 	 val=96480  sum_mul= 57395491
# 	 val=0  sum_mul= 57395491
# ================================================================================
# 0 11 -1
# A traiter :  mul(883,425)
# ==> OK
# 	 val=375275  sum_mul= 57770766
# 	 val=0  sum_mul= 57770766
# ================================================================================
# 0 11 -1
# A traiter :  mul(499,161)
# ==> OK
# 	 val=80339  sum_mul= 57851105
# 	 val=0  sum_mul= 57851105
# ================================================================================
# 0 11 -1
# A traiter :  mul(739,922)
# ==> OK
# 	 val=681358  sum_mul= 58532463
# 	 val=0  sum_mul= 58532463
# ================================================================================
# 0 10 -1
# A traiter :  mul(139,18)
# ==> OK
# 	 val=2502  sum_mul= 58534965
# 	 val=0  sum_mul= 58534965
# ================================================================================
# 0 11 -1
# A traiter :  mul(387,314)
# ==> OK
# 	 val=121518  sum_mul= 58656483
# 	 val=0  sum_mul= 58656483
# ================================================================================
# 0 10 -1
# A traiter :  mul(700,20)
# ==> OK
# 	 val=14000  sum_mul= 58670483
# 	 val=0  sum_mul= 58670483
# ================================================================================
# 0 11 -1
# A traiter :  mul(831,842)
# ==> OK
# 	 val=699702  sum_mul= 59370185
# 	 val=0  sum_mul= 59370185
# ================================================================================
# 0 10 -1
# A traiter :  mul(94,652)
# ==> OK
# 	 val=61288  sum_mul= 59431473
# 	 val=0  sum_mul= 59431473
# ================================================================================
# 0 11 -1
# A traiter :  mul(432,288)
# ==> OK
# 	 val=124416  sum_mul= 59555889
# 	 val=0  sum_mul= 59555889
# ================================================================================
# 0 11 -1
# A traiter :  mul(784,887)
# ==> OK
# 	 val=695408  sum_mul= 60251297
# 	 val=0  sum_mul= 60251297
# ================================================================================
# 0 10 -1
# A traiter :  mul(533,25)
# ==> OK
# 	 val=13325  sum_mul= 60264622
# 	 val=0  sum_mul= 60264622
# ================================================================================
# 0 10 -1
# A traiter :  mul(143,52)
# ==> OK
# 	 val=7436  sum_mul= 60272058
# 	 val=0  sum_mul= 60272058
# ================================================================================
# 0 11 -1
# A traiter :  mul(642,343)
# ==> OK
# 	 val=220206  sum_mul= 60492264
# 	 val=0  sum_mul= 60492264
# ================================================================================
# 0 11 -1
# A traiter :  mul(189,424)
# ==> OK
# 	 val=80136  sum_mul= 60572400
# 	 val=0  sum_mul= 60572400
# ================================================================================
# 0 10 -1
# A traiter :  mul(793,39)
# ==> OK
# 	 val=30927  sum_mul= 60603327
# 	 val=0  sum_mul= 60603327
# ================================================================================
# 0 10 -1
# A traiter :  mul(177,19)
# ==> OK
# 	 val=3363  sum_mul= 60606690
# 	 val=0  sum_mul= 60606690
# ================================================================================
# 0 11 -1
# A traiter :  mul(353,731)
# ==> OK
# 	 val=258043  sum_mul= 60864733
# 	 val=0  sum_mul= 60864733
# ================================================================================
# 0 11 -1
# A traiter :  mul(905,243)
# ==> OK
# 	 val=219915  sum_mul= 61084648
# 	 val=0  sum_mul= 61084648
# ================================================================================
# 0 11 -1
# A traiter :  mul(858,664)
# ==> OK
# 	 val=569712  sum_mul= 61654360
# 	 val=0  sum_mul= 61654360
# ================================================================================
# 0 11 -1
# A traiter :  mul(441,712)
# ==> OK
# 	 val=313992  sum_mul= 61968352
# 	 val=0  sum_mul= 61968352
# ================================================================================
# 0 11 -1
# A traiter :  mul(195,765)
# ==> OK
# 	 val=149175  sum_mul= 62117527
# 	 val=0  sum_mul= 62117527
# ================================================================================
# 0 11 -1
# A traiter :  mul(359,972)
# ==> OK
# 	 val=348948  sum_mul= 62466475
# 	 val=0  sum_mul= 62466475
# ================================================================================
# 0 11 -1
# A traiter :  mul(214,820)
# ==> OK
# 	 val=175480  sum_mul= 62641955
# 	 val=0  sum_mul= 62641955
# ================================================================================
# 0 11 -1
# A traiter :  mul(120,471)
# ==> OK
# 	 val=56520  sum_mul= 62698475
# 	 val=0  sum_mul= 62698475
# ================================================================================
# 0 11 -1
# A traiter :  mul(773,429)
# ==> OK
# 	 val=331617  sum_mul= 63030092
# 	 val=0  sum_mul= 63030092
# ================================================================================
# 0 11 -1
# A traiter :  mul(906,233)
# ==> OK
# 	 val=211098  sum_mul= 63241190
# 	 val=0  sum_mul= 63241190
# ================================================================================
# 0 11 -1
# A traiter :  mul(248,396)
# ==> OK
# 	 val=98208  sum_mul= 63339398
# 	 val=0  sum_mul= 63339398
# ================================================================================
# 0 11 -1
# A traiter :  mul(831,308)
# ==> OK
# 	 val=255948  sum_mul= 63595346
# 	 val=0  sum_mul= 63595346
# ================================================================================
# 0 11 -1
# A traiter :  mul(449,285)
# ==> OK
# 	 val=127965  sum_mul= 63723311
# 	 val=0  sum_mul= 63723311
# ================================================================================
# 0 10 -1
# A traiter :  mul(88,963)
# ==> OK
# 	 val=84744  sum_mul= 63808055
# 	 val=0  sum_mul= 63808055
# ================================================================================
# 0 11 -1
# A traiter :  mul(616,800)
# ==> OK
# 	 val=492800  sum_mul= 64300855
# 	 val=0  sum_mul= 64300855
# ================================================================================
# 0 11 -1
# A traiter :  mul(267,952)
# ==> OK
# 	 val=254184  sum_mul= 64555039
# 	 val=0  sum_mul= 64555039
# ================================================================================
# 0 10 -1
# A traiter :  mul(57,449)
# ==> OK
# 	 val=25593  sum_mul= 64580632
# 	 val=0  sum_mul= 64580632
# ================================================================================
# 0 11 -1
# A traiter :  mul(132,365)
# ==> OK
# 	 val=48180  sum_mul= 64628812
# 	 val=0  sum_mul= 64628812
# ================================================================================
# 0 10 -1
# A traiter :  mul(12,905)
# ==> OK
# 	 val=10860  sum_mul= 64639672
# 	 val=0  sum_mul= 64639672
# ================================================================================
# 0 10 -1
# A traiter :  mul(833,41)
# ==> OK
# 	 val=34153  sum_mul= 64673825
# 	 val=0  sum_mul= 64673825
# ================================================================================
# 0 11 -1
# A traiter :  mul(190,804)
# ==> OK
# 	 val=152760  sum_mul= 64826585
# 	 val=0  sum_mul= 64826585
# ================================================================================
# 0 11 -1
# A traiter :  mul(332,666)
# ==> OK
# 	 val=221112  sum_mul= 65047697
# 	 val=0  sum_mul= 65047697
# ================================================================================
# 0 11 -1
# A traiter :  mul(121,100)
# ...
# 	 val=0  sum_mul= 151985482
# ================================================================================
# 0 11 -1
# A traiter :  mul(225,216)
# ==> OK
# 	 val=48600  sum_mul= 152034082
# 	 val=0  sum_mul= 152034082
# ================================================================================
# 0 11 -1
# A traiter :  mul(126,101)
# ==> OK
# 	 val=12726  sum_mul= 152046808
# 	 val=0  sum_mul= 152046808
# ================================================================================
# 0 11 -1
# A traiter :  mul(115,508)
# ==> OK
# 	 val=58420  sum_mul= 152105228
# 	 val=0  sum_mul= 152105228
# ================================================================================
# 0 10 -1
# A traiter :  mul(526,56)
# ==> OK
# 	 val=29456  sum_mul= 152134684
# 	 val=0  sum_mul= 152134684
# ================================================================================
# 0 11 -1
# A traiter :  mul(983,261)
# ==> OK
# 	 val=256563  sum_mul= 152391247
# 	 val=0  sum_mul= 152391247
# ================================================================================
# 0 11 -1
# A traiter :  mul(120,494)
# ==> OK
# 	 val=59280  sum_mul= 152450527
# 	 val=0  sum_mul= 152450527
# ================================================================================
# 0 11 -1
# A traiter :  mul(844,887)
# ==> OK
# 	 val=748628  sum_mul= 153199155
# 	 val=0  sum_mul= 153199155
# ================================================================================
# 0 11 -1
# A traiter :  mul(362,649)
# ==> OK
# 	 val=234938  sum_mul= 153434093
# 	 val=0  sum_mul= 153434093
# ================================================================================
# 0 11 -1
# A traiter :  mul(860,454)
# ==> OK
# 	 val=390440  sum_mul= 153824533
# 	 val=0  sum_mul= 153824533
# ================================================================================
# 0 11 -1
# A traiter :  mul(641,456)
# ==> OK
# 	 val=292296  sum_mul= 154116829
# 	 val=0  sum_mul= 154116829
# ================================================================================
# 0 11 -1
# A traiter :  mul(680,795)
# ==> OK
# 	 val=540600  sum_mul= 154657429
# 	 val=0  sum_mul= 154657429
# ================================================================================
# 0 10 -1
# A traiter :  mul(615,47)
# ==> OK
# 	 val=28905  sum_mul= 154686334
# 	 val=0  sum_mul= 154686334
# ================================================================================
# 0 11 -1
# A traiter :  mul(164,546)
# ==> OK
# 	 val=89544  sum_mul= 154775878
# 	 val=0  sum_mul= 154775878
# ================================================================================
# 0 11 -1
# A traiter :  mul(362,611)
# ==> OK
# 	 val=221182  sum_mul= 154997060
# 	 val=0  sum_mul= 154997060
# ================================================================================
# 0 11 -1
# A traiter :  mul(988,879)
# ==> OK
# 	 val=868452  sum_mul= 155865512
# 	 val=0  sum_mul= 155865512
# ================================================================================
# 0 11 -1
# A traiter :  mul(793,977)
# ==> OK
# 	 val=774761  sum_mul= 156640273
# 	 val=0  sum_mul= 156640273
# ================================================================================
# 0 11 -1
# A traiter :  mul(180,977)
# ==> OK
# 	 val=175860  sum_mul= 156816133
# 	 val=0  sum_mul= 156816133
# ================================================================================
# 0 11 -1
# A traiter :  mul(650,960)
# ==> OK
# 	 val=624000  sum_mul= 157440133
# 	 val=0  sum_mul= 157440133
# ================================================================================
# 0 10 -1
# A traiter :  mul(126,38)
# ==> OK
# 	 val=4788  sum_mul= 157444921
# 	 val=0  sum_mul= 157444921
# ================================================================================
# 0 11 -1
# A traiter :  mul(691,993)
# ==> OK
# 	 val=686163  sum_mul= 158131084
# 	 val=0  sum_mul= 158131084
# ================================================================================
# 0 11 -1
# A traiter :  mul(807,183)
# ==> OK
# 	 val=147681  sum_mul= 158278765
# 	 val=0  sum_mul= 158278765
# ================================================================================
# 0 11 -1
# A traiter :  mul(598,303)
# ==> OK
# 	 val=181194  sum_mul= 158459959
# 	 val=0  sum_mul= 158459959
# ================================================================================
# 0 11 -1
# A traiter :  mul(261,676)
# ==> OK
# 	 val=176436  sum_mul= 158636395
# 	 val=0  sum_mul= 158636395
# ================================================================================
# 0 11 -1
# A traiter :  mul(859,361)
# ==> OK
# 	 val=310099  sum_mul= 158946494
# 	 val=0  sum_mul= 158946494
# ================================================================================
# 0 11 -1
# A traiter :  mul(575,974)
# ==> OK
# 	 val=560050  sum_mul= 159506544
# 	 val=0  sum_mul= 159506544
# ================================================================================
# 0 11 -1
# A traiter :  mul(689,411)
# ==> OK
# 	 val=283179  sum_mul= 159789723
# 	 val=0  sum_mul= 159789723
# ================================================================================
# 0 11 -1
# A traiter :  mul(220,253)
# ==> OK
# 	 val=55660  sum_mul= 159845383
# 	 val=0  sum_mul= 159845383
# ================================================================================
# 0 11 -1
# A traiter :  mul(580,348)
# ==> OK
# 	 val=201840  sum_mul= 160047223
# 	 val=0  sum_mul= 160047223
# ================================================================================
# 0 11 -1
# A traiter :  mul(312,291)
# ==> OK
# 	 val=90792  sum_mul= 160138015
# 	 val=0  sum_mul= 160138015
# ================================================================================
# 0 11 -1
# A traiter :  mul(811,784)
# ==> OK
# 	 val=635824  sum_mul= 160773839
# 	 val=0  sum_mul= 160773839
# ================================================================================
# 0 11 -1
# A traiter :  mul(111,750)
# ==> OK
# 	 val=83250  sum_mul= 160857089
# 	 val=0  sum_mul= 160857089
# ================================================================================
# 0 11 -1
# A traiter :  mul(262,914)
# ==> OK
# 	 val=239468  sum_mul= 161096557
# 	 val=0  sum_mul= 161096557
# ================================================================================
# 0 10 -1
# A traiter :  mul(912,50)
# ==> OK
# 	 val=45600  sum_mul= 161142157
# 	 val=0  sum_mul= 161142157
# ================================================================================
# 0 11 -1
# A traiter :  mul(266,671)
# ==> OK
# 	 val=178486  sum_mul= 161320643
# 	 val=0  sum_mul= 161320643
# ================================================================================
# 0 10 -1
# A traiter :  mul(198,55)
# ==> OK
# 	 val=10890  sum_mul= 161331533
# 	 val=0  sum_mul= 161331533
# ================================================================================
# 0 11 -1
# A traiter :  mul(639,758)
# ==> OK
# 	 val=484362  sum_mul= 161815895
# 	 val=0  sum_mul= 161815895
# ================================================================================
# 0 11 -1
# A traiter :  mul(778,355)
# ==> OK
# 	 val=276190  sum_mul= 162092085
# 	 val=0  sum_mul= 162092085
# ================================================================================
# 0 11 -1
# A traiter :  mul(671,952)
# ==> OK
# 	 val=638792  sum_mul= 162730877
# 	 val=0  sum_mul= 162730877
# ================================================================================
# 0 9 -1
# A traiter :  mul(49,99)
# ==> OK
# 	 val=4851  sum_mul= 162735728
# 	 val=0  sum_mul= 162735728
# ================================================================================
# 0 11 -1
# A traiter :  mul(716,339)
# ==> OK
# 	 val=242724  sum_mul= 162978452
# 	 val=0  sum_mul= 162978452
# ================================================================================
# 0 11 -1
# A traiter :  mul(809,820)
# ==> OK
# 	 val=663380  sum_mul= 163641832
# 	 val=0  sum_mul= 163641832
# ================================================================================
# 0 11 -1
# A traiter :  mul(817,469)
# ==> OK
# 	 val=383173  sum_mul= 164025005
# 	 val=0  sum_mul= 164025005
# ================================================================================
# 0 11 -1
# A traiter :  mul(298,722)
# ==> OK
# 	 val=215156  sum_mul= 164240161
# 	 val=0  sum_mul= 164240161
# ================================================================================
# 0 11 -1
# A traiter :  mul(966,895)
# ==> OK
# 	 val=864570  sum_mul= 165104731
# 	 val=0  sum_mul= 165104731
# ================================================================================
# 0 11 -1
# A traiter :  mul(280,502)
# ==> OK
# 	 val=140560  sum_mul= 165245291
# 	 val=0  sum_mul= 165245291
# ================================================================================
# 0 11 -1
# A traiter :  mul(662,666)
# ==> OK
# 	 val=440892  sum_mul= 165686183
# 	 val=0  sum_mul= 165686183
# ================================================================================
# 0 11 -1
# A traiter :  mul(144,933)
# ==> OK
# 	 val=134352  sum_mul= 165820535
# 	 val=0  sum_mul= 165820535
# ================================================================================
# 0 9 -1
# A traiter :  mul(46,58)
# ==> OK
# 	 val=2668  sum_mul= 165823203
# 	 val=0  sum_mul= 165823203
# ================================================================================
# 0 11 -1
# A traiter :  mul(230,718)
# ==> OK
# 	 val=165140  sum_mul= 165988343
# 	 val=0  sum_mul= 165988343
# ================================================================================
# 0 11 -1
# A traiter :  mul(896,471)
# ==> OK
# 	 val=422016  sum_mul= 166410359
# 	 val=0  sum_mul= 166410359
# ================================================================================
# 0 11 -1
# A traiter :  mul(755,690)
# ==> OK
# 	 val=520950  sum_mul= 166931309
# 	 val=0  sum_mul= 166931309
# ================================================================================
# 0 11 -1
# A traiter :  mul(369,519)
# ==> OK
# 	 val=191511  sum_mul= 167122820
# 	 val=0  sum_mul= 167122820
# ================================================================================
# 0 11 -1
# A traiter :  mul(104,644)
# ==> OK
# 	 val=66976  sum_mul= 167189796
# 	 val=0  sum_mul= 167189796
# ================================================================================
# 0 11 -1
# A traiter :  mul(650,245)
# ==> OK
# 	 val=159250  sum_mul= 167349046
# 	 val=0  sum_mul= 167349046
# ================================================================================
# 0 11 -1
# A traiter :  mul(194,733)
# ==> OK
# 	 val=142202  sum_mul= 167491248
# 	 val=0  sum_mul= 167491248
# ================================================================================
# 0 11 -1
# A traiter :  mul(758,991)
# ==> OK
# 	 val=751178  sum_mul= 168242426
# 	 val=0  sum_mul= 168242426
# ================================================================================
# 0 11 -1
# A traiter :  mul(433,514)
# ==> OK
# 	 val=222562  sum_mul= 168464988
# 	 val=0  sum_mul= 168464988
# ================================================================================
# 0 11 -1
# A traiter :  mul(354,478)
# ==> OK
# 	 val=169212  sum_mul= 168634200
# 	 val=0  sum_mul= 168634200
# ================================================================================
# 0 11 -1
# A traiter :  mul(730,407)
# ==> OK
# 	 val=297110  sum_mul= 168931310
# 	 val=0  sum_mul= 168931310
# ================================================================================
# 0 9 -1
# A traiter :  mul(4,496)
# ==> OK
# 	 val=1984  sum_mul= 168933294
# 	 val=0  sum_mul= 168933294
# ================================================================================
# 0 10 -1
# A traiter :  mul(805,37)
# ==> OK
# 	 val=29785  sum_mul= 168963079
# 	 val=0  sum_mul= 168963079
# ================================================================================
# 0 10 -1
# A traiter :  mul(88,378)
# ==> OK
# 	 val=33264  sum_mul= 168996343
# 	 val=0  sum_mul= 168996343
# ================================================================================
# 0 11 -1
# A traiter :  mul(686,789)
# ==> OK
# 	 val=541254  sum_mul= 169537597
# 	 val=0  sum_mul= 169537597
# ================================================================================
# 0 11 -1
# A traiter :  mul(492,312)
# ==> OK
# 	 val=153504  sum_mul= 169691101
# 	 val=0  sum_mul= 169691101
# ================================================================================
# 0 10 -1
# A traiter :  mul(282,80)
# ==> OK
# 	 val=22560  sum_mul= 169713661
# 	 val=0  sum_mul= 169713661
# ================================================================================
# 0 11 -1
# A traiter :  mul(319,810)
# ==> OK
# 	 val=258390  sum_mul= 169972051
# 	 val=0  sum_mul= 169972051
# ================================================================================
# 0 11 -1
# A traiter :  mul(790,584)
# ==> OK
# 	 val=461360  sum_mul= 170433411
# 	 val=0  sum_mul= 170433411
# ================================================================================
# 0 11 -1
# A traiter :  mul(675,258)
# ==> OK
# 	 val=174150  sum_mul= 170607561
# 	 val=0  sum_mul= 170607561
# ================================================================================
# 0 11 -1
# A traiter :  mul(179,413)
# ==> OK
# 	 val=73927  sum_mul= 170681488
# 	 val=0  sum_mul= 170681488
# ================================================================================
# 0 11 -1
# A traiter :  mul(981,563)
# ==> OK
# 	 val=552303  sum_mul= 171233791
# 	 val=0  sum_mul= 171233791
# ================================================================================
# 0 11 -1
# A traiter :  mul(522,474)
# ==> OK
# 	 val=247428  sum_mul= 171481219
# 	 val=0  sum_mul= 171481219
# ================================================================================
# 0 11 -1
# A traiter :  mul(777,123)
# ==> OK
# 	 val=95571  sum_mul= 171576790
# 	 val=0  sum_mul= 171576790
# ================================================================================
# 0 11 -1
# A traiter :  mul(815,110)
# ==> OK
# 	 val=89650  sum_mul= 171666440
# 	 val=0  sum_mul= 171666440
# ================================================================================
# 0 11 -1
# A traiter :  mul(476,634)
# ==> OK
# 	 val=301784  sum_mul= 171968224
# 	 val=0  sum_mul= 171968224
# ================================================================================
# 0 11 -1
# A traiter :  mul(409,191)
# ==> OK
# 	 val=78119  sum_mul= 172046343
# 	 val=0  sum_mul= 172046343
# ================================================================================
# 0 11 -1
# A traiter :  mul(961,701)
# ==> OK
# 	 val=673661  sum_mul= 172720004
# 	 val=0  sum_mul= 172720004
# ================================================================================
# 0 11 -1
# A traiter :  mul(261,730)
# ==> OK
# 	 val=190530  sum_mul= 172910534
# 	 val=0  sum_mul= 172910534
# ================================================================================
# 0 11 -1
# A traiter :  mul(516,261)
# ==> OK
# 	 val=134676  sum_mul= 173045210
# 	 val=0  sum_mul= 173045210
# ================================================================================
# 0 10 -1
# A traiter :  mul(63,590)
# ==> OK
# 	 val=37170  sum_mul= 173082380
# 	 val=0  sum_mul= 173082380
# ================================================================================
# 0 11 -1
# A traiter :  mul(361,903)
# ==> OK
# 	 val=325983  sum_mul= 173408363
# 	 val=0  sum_mul= 173408363
# ================================================================================
# 0 11 -1
# A traiter :  mul(293,942)
# ==> OK
# 	 val=276006  sum_mul= 173684369
# 	 val=0  sum_mul= 173684369
# ================================================================================
# 0 11 -1
# A traiter :  mul(568,142)
# ==> OK
# 	 val=80656  sum_mul= 173765025
# 	 val=0  sum_mul= 173765025
# ================================================================================
# 0 10 -1
# A traiter :  mul(725,32)
# ==> OK
# 	 val=23200  sum_mul= 173788225
# 	 val=0  sum_mul= 173788225
# ================================================================================
# 0 11 -1
# A traiter :  mul(353,931)
# ==> OK
# 	 val=328643  sum_mul= 174116868
# 	 val=0  sum_mul= 174116868
# ================================================================================
# 0 11 -1
# A traiter :  mul(452,478)
# ==> OK
# 	 val=216056  sum_mul= 174332924
# 	 val=0  sum_mul= 174332924
# ================================================================================
# 0 11 -1
# A traiter :  mul(465,609)
# ==> OK
# 	 val=283185  sum_mul= 174616109
# 	 val=0  sum_mul= 174616109
# ================================================================================
# 0 11 -1
# A traiter :  mul(527,755)
# ==> OK
# 	 val=397885  sum_mul= 175013994
# 	 val=0  sum_mul= 175013994
# ================================================================================
# 175013994

# %%
corrupted_data[1]
# Out:
# 'mul(307,210)\n'

# %%
get_mul_str(corrupted_data[1],0)
# Out:
# 0 11 -1
# A traiter :  mul(307,210)
# ==> OK
# (64470, 11, True)

# %%
st="xmul(2,4)%&mul[3,7]!@^do_not_mul(5,5)+mul(32,64]then(mul(11,8)mul(8,5))"
sum_mul = 0                                          
position = 0
proceed = True
while proceed :
    val,position,proceed = get_mul_str(st,position)
    sum_mul += val
    print(f"reste: {st[position:]=}")
# Out:
# 1 8 29
# A traiter :  mul(2,4)
# ==> OK
# reste: st[position:]=')%&mul[3,7]!@^do_not_mul(5,5)+mul(32,64]then(mul(11,8)mul(8,5))'
# 29 36 38
# A traiter :  mul(5,5)
# ==> OK
# reste: st[position:]=')+mul(32,64]then(mul(11,8)mul(8,5))'
# 38 61 53
# reste: st[position:]='mul(11,8)mul(8,5))'
# 53 61 62
# A traiter :  mul(11,8)
# ==> OK
# reste: st[position:]=')mul(8,5))'
# 62 69 -1
# A traiter :  mul(8,5)
# ==> OK
# reste: st[position:]='))'
# reste: st[position:]=')'

# %%
# Out:
# ['mul(2,4)%&mul[3,7]!@^do_not_mul(5,5)+mul(32,64]then(mul(11,8)mul(8,5)']
